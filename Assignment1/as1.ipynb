# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Hanjie Liu
#
# Student ID: 1667156

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Wednesday, 26 March 2025 1pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -20% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python on Google Colab" page on Canvas (under Modules>Resources) for information on how to use Google Colab to use Jupyter Notebook. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages, <b> except </b> Numpy, Scipy, Matplotlib, Scikit-Learn, Gensim, Keras and Pytorch. You must export your Colab notebook and submit it to the LMS. If your notebook doesn't run, you will lose marks. <b> You should use the Python version that's on Google Colab (3.10)</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place. You <b> must not </b> use artifial intelligence tools for doing the assignment, as all work submitted by a student should be their own, as clarified <a href="https://academicintegrity.unimelb.edu.au/plagiarism-and-collusion/artificial-intelligence-tools-and-technologies">here</a>.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English letters in the alphabet (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
nltk.download('stopwords')
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from collections import Counter
import re

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase
def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    x_processed = []
    y_processed = []
    
    for i in range(len(data)):
        data_list = data[i].lower()
        data_list = tt.tokenize(str(data_list))
        data_list = [word for word in data_list if word not in stopwords]
        data_list = [word for word in data_list if not re.fullmatch(r"[^\w\d]+", word)]
        data_list = [word for word in data_list if not word.isdigit()]

        data_count = dict(Counter(data_list))
        #print(data_count.items())
        if data_count != {}:
            #print(set(data_count.items()))
            x_processed.append(data_count)
            y_processed.append(labels[i])

    return x_processed, y_processed
    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1}
# Country = us 	Tweet = {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1}
# Country = ph 	Tweet = {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1}
# Country = id 	Tweet = {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1}
# Country = ph 	Tweet = {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1}
# Country = gb 	Tweet = {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1}
# Country = my 	Tweet = {'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, 'others': 1, 'http://t.co/bcnobykz': 1}
# Country = us 	Tweet = {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1}
# Country = gb 	Tweet = {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lhg45\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet
nltk.download('words')
nltk.download('wordnet')

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###

    hashtag_dict = {}
    print(hashtags)

    for hashtag in hashtags:
        hashtag = hashtag[1:]
        hashtag = hashtag.lower()

        start_pointer = 0
        i = len(hashtag)

        hashtag_list = ['#']
        
        while i != start_pointer:
            if lemmatize(hashtag[start_pointer:i]) in words:
                #print("find match: " , hashtag[start_pointer:i])
                hashtag_list.append(hashtag[start_pointer:i])
                start_pointer = i
                i = len(hashtag)
            else:
                i -= 1
                
        if start_pointer != i:
            #print(hashtag[start_pointer:i])
            hashtag_list.append(hashtag[start_pointer:i])

        hashtag_dict['#'+hashtag] = hashtag_list

    return hashtag_dict
    ###
    # Your answer ENDS HERE
    ###

#tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\lhg45\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lhg45\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# {'#taintedlove', '#asksteven', '#wearesocial', '#sunrise', '#mobile', '#nochillzone', '#die', '#them', '#massacreconspiracy', '#insanity', '#usydhereicome', '#reachingyougpeople', '#big', '#laundryservice', '#makingemuklajawabnya', '#stkilda', '#ariona', '#burgers', '#stop', '#uss', '#cornell', '#turbine', '#jewelry', '#lovevibes', '#kllive', '#newrecord', '#revfcwh', '#peperoni', '#insightmedia', '#hb60', '#dennisrodman', '#bluemountains', '#bayofislands', '#voteonedirection', '#rundude', '#ashes', '#sorrynotsorry', '#1yearofalmostisneverenough', '#longranger', '#fried', '#ahimacon14', '#fries', '#election2015', '#walking', '#thankful', '#pic', '#thaifood', '#askolly', '#greenfood', '#booyaa', '#magic', '#insightmediasingapore', '#engine', '#march', '#colts', '#thomassabo', '#fridaynight', '#at', '#excitables', '#fotografías', '#breedingground', '#urbangardening', '#makeupfree', '#ladygaga', '#data', '#yellow', '#blessedmorethanicanimagine', '#vegan', '#thursday', '#redbull', '#ujackbastards', '#stopcomplaining', '#fabulous', '#sycip', '#electriccircus2014', '#skeemsaam', '#movies', '#hungergames', '#lol', '#ynwa', '#magazinesandtvscreens', '#statoftheday', '#thenext5goldenyears', '#canadaelections', '#fly', '#olah', '#vsco', '#latepost', '#flashback', '#affsuzukicup', '#eeeeeehhh', '#bigbreakfast', '#bye', '#photography', '#mybabyemilia', '#dearmind', '#lgbt', '#allcity', '#5sosfam', '#world', '#rosegold', '#gunner', '#sarahm', '#hollywoodmusicawards', '#hippy', '#girls', '#justshare', '#shellvpower', '#saulbass', '#country', '#strictlyus', '#hens', '#bradersisterhood', '#sfgiants', '#uniexamonasaturday', '#askherforfback', '#ididntchoosethestudentlifeitchoseme', '#pll', '#np', '#grilled', '#southampton', '#thankyoulord', '#ciosummit', '#thecolorrun2014', '#vanilla', '#thewalkingdead', '#truegrip', '#bored', '#airasia', '#work', '#wood', '#innoretail', '#focusateneo', '#awesomepict', '#dynamounlock', '#shakethatbooty', '#art', '#sinvsmas', '#boredom', '#datingsiteforyou', '#silver', '#hot', '#purplefriday', '#getfreetattooaviciipasses', '#askcrawford', '#design', '#blessedsunday', '#toronto', '#chargers', '#ohyeah', '#rt', '#blackhat', '#happyfriday', '#thevoiceau', '#freaks', '#beautiful', '#photo', '#takeabreak', '#creative', '#pmattheashes', '#instaframeplus', '#coffeespoonart', '#life', '#tpcoach', '#dragoncon', '#txlege', '#morning', '#deed', '#artwork', '#shakes', '#summer', '#confused', '#bell', '#google', '#bigbertha', '#mtlnewtech', '#yws13', '#isibaya', '#devacurl', '#sexy', '#bart', '#boomtaob', '#white', '#mauce', '#girlcrush', '#notersnew2014', '#lfc', '#nofilter', '#spider', '#rose', '#of', '#sandwich', '#mustfollow', '#instalook', '#swedumtl', '#cbb', '#fun', '#realgoodbikes', '#grammyfans', '#surfshop', '#loadsoffun', '#peppermoney', '#youtube', '#friends', '#learningcommunties', '#goingout', '#factorycampus', '#tennis', '#shopaholic', '#mkmedi', '#penny', '#skullsearcher', '#brooksengland', '#australia', '#ncpol', '#flambees', '#lovethisgirl', '#diner', '#veganfood', '#nced', '#thedisadvantagesofakindle', '#weare90s', '#imsobored', '#foodporn', '#startupfest', '#nfl', '#1stsundayofoctober', '#four', '#endomondo', '#butitsalsokindofaphone', '#asian', '#tdwpliveinkl', '#lipstickfree', '#rainorshine', '#gudnytall', '#aim20', '#future', '#retail', '#photoby', '#jo', '#365picture', '#givesmehope', '#teamcanada', '#jed', '#newlooks', '#thaiexpress', '#potd', '#fotorus', '#difd', '#mwc14', '#ticklish', '#procrastination', '#scifigeek', '#dus', '#2k16', '#celebritycrush', '#pop-up', '#sl', '#hungry', '#wings', '#galaxy', '#hometomama', '#shenanigans', '#new', '#me', '#rollersmusicawards', '#rollercoaster', '#thankyoupatients', '#vma', '#lazysunday', '#oilandgas', '#promise', '#oops', '#awesome', '#followme', '#crepes', '#anferneehardaway', '#spicy', '#pechanga', '#friendshipflow', '#mancrush', '#myfriendsarebetterthanyours', '#stampede2014', '#tcschleissheim', '#universal', '#bringithomemy', '#grandmarnier', '#mount ...
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'coca', 'm']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e']
# #wearesocial ['#', 'weares', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    hashtag_dict = {}
    print(hashtags)

    for hashtag in hashtags:
        hashtag = hashtag[1:]
        hashtag = hashtag.lower()

        end_pointer = len(hashtag)
        i = 0
        hashtag_list = ['#']
        
        while i != end_pointer:
            if lemmatize(hashtag[i:end_pointer]) in words:
                #print("find match: " , hashtag[start_pointer:i])
                hashtag_list.insert(1, hashtag[i:end_pointer])
                end_pointer = i
                i = 0
            else:
                i += 1
                
        if end_pointer != i:
            #print(hashtag[start_pointer:i])
            hashtag_list.insert(1, hashtag[i:end_pointer])

        hashtag_dict['#'+hashtag] = hashtag_list

    return hashtag_dict

    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# {'#taintedlove', '#asksteven', '#wearesocial', '#sunrise', '#mobile', '#nochillzone', '#die', '#them', '#massacreconspiracy', '#insanity', '#usydhereicome', '#reachingyougpeople', '#big', '#laundryservice', '#makingemuklajawabnya', '#stkilda', '#ariona', '#burgers', '#stop', '#uss', '#cornell', '#turbine', '#jewelry', '#lovevibes', '#kllive', '#newrecord', '#revfcwh', '#peperoni', '#insightmedia', '#hb60', '#dennisrodman', '#bluemountains', '#bayofislands', '#voteonedirection', '#rundude', '#ashes', '#sorrynotsorry', '#1yearofalmostisneverenough', '#longranger', '#fried', '#ahimacon14', '#fries', '#election2015', '#walking', '#thankful', '#pic', '#thaifood', '#askolly', '#greenfood', '#booyaa', '#magic', '#insightmediasingapore', '#engine', '#march', '#colts', '#thomassabo', '#fridaynight', '#at', '#excitables', '#fotografías', '#breedingground', '#urbangardening', '#makeupfree', '#ladygaga', '#data', '#yellow', '#blessedmorethanicanimagine', '#vegan', '#thursday', '#redbull', '#ujackbastards', '#stopcomplaining', '#fabulous', '#sycip', '#electriccircus2014', '#skeemsaam', '#movies', '#hungergames', '#lol', '#ynwa', '#magazinesandtvscreens', '#statoftheday', '#thenext5goldenyears', '#canadaelections', '#fly', '#olah', '#vsco', '#latepost', '#flashback', '#affsuzukicup', '#eeeeeehhh', '#bigbreakfast', '#bye', '#photography', '#mybabyemilia', '#dearmind', '#lgbt', '#allcity', '#5sosfam', '#world', '#rosegold', '#gunner', '#sarahm', '#hollywoodmusicawards', '#hippy', '#girls', '#justshare', '#shellvpower', '#saulbass', '#country', '#strictlyus', '#hens', '#bradersisterhood', '#sfgiants', '#uniexamonasaturday', '#askherforfback', '#ididntchoosethestudentlifeitchoseme', '#pll', '#np', '#grilled', '#southampton', '#thankyoulord', '#ciosummit', '#thecolorrun2014', '#vanilla', '#thewalkingdead', '#truegrip', '#bored', '#airasia', '#work', '#wood', '#innoretail', '#focusateneo', '#awesomepict', '#dynamounlock', '#shakethatbooty', '#art', '#sinvsmas', '#boredom', '#datingsiteforyou', '#silver', '#hot', '#purplefriday', '#getfreetattooaviciipasses', '#askcrawford', '#design', '#blessedsunday', '#toronto', '#chargers', '#ohyeah', '#rt', '#blackhat', '#happyfriday', '#thevoiceau', '#freaks', '#beautiful', '#photo', '#takeabreak', '#creative', '#pmattheashes', '#instaframeplus', '#coffeespoonart', '#life', '#tpcoach', '#dragoncon', '#txlege', '#morning', '#deed', '#artwork', '#shakes', '#summer', '#confused', '#bell', '#google', '#bigbertha', '#mtlnewtech', '#yws13', '#isibaya', '#devacurl', '#sexy', '#bart', '#boomtaob', '#white', '#mauce', '#girlcrush', '#notersnew2014', '#lfc', '#nofilter', '#spider', '#rose', '#of', '#sandwich', '#mustfollow', '#instalook', '#swedumtl', '#cbb', '#fun', '#realgoodbikes', '#grammyfans', '#surfshop', '#loadsoffun', '#peppermoney', '#youtube', '#friends', '#learningcommunties', '#goingout', '#factorycampus', '#tennis', '#shopaholic', '#mkmedi', '#penny', '#skullsearcher', '#brooksengland', '#australia', '#ncpol', '#flambees', '#lovethisgirl', '#diner', '#veganfood', '#nced', '#thedisadvantagesofakindle', '#weare90s', '#imsobored', '#foodporn', '#startupfest', '#nfl', '#1stsundayofoctober', '#four', '#endomondo', '#butitsalsokindofaphone', '#asian', '#tdwpliveinkl', '#lipstickfree', '#rainorshine', '#gudnytall', '#aim20', '#future', '#retail', '#photoby', '#jo', '#365picture', '#givesmehope', '#teamcanada', '#jed', '#newlooks', '#thaiexpress', '#potd', '#fotorus', '#difd', '#mwc14', '#ticklish', '#procrastination', '#scifigeek', '#dus', '#2k16', '#celebritycrush', '#pop-up', '#sl', '#hungry', '#wings', '#galaxy', '#hometomama', '#shenanigans', '#new', '#me', '#rollersmusicawards', '#rollercoaster', '#thankyoupatients', '#vma', '#lazysunday', '#oilandgas', '#promise', '#oops', '#awesome', '#followme', '#crepes', '#anferneehardaway', '#spicy', '#pechanga', '#friendshipflow', '#mancrush', '#myfriendsarebetterthanyours', '#stampede2014', '#tcschleissheim', '#universal', '#bringithomemy', '#grandmarnier', '#mount ...
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gan']
# #veganfood ['#', 'v', 'e', 'gan', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'c', 'o', 'cam']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 's']
# #wearesocial ['#', 'we', 'are', 'social']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'mas']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hello</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import math

#words from brown corpus
nltk.download('brown')
brown_words = brown.words()

###
# Your answer BEGINS HERE
###

#Add-one smoothing
word_freq = dict()
for word in brown_words:
    word = word.lower()
    word_freq[word] = word_freq.get(word, 0) + 1
        
word_total = sum(word_freq.values())

idx = 0
for hashtag in hashtags:

    tokenised_hashtag = tokenized_hashtags[hashtag][1:]
    tokenised_hashtag_rev = tokenized_hashtags_rev[hashtag][1:]

    log_prob = 0
    log_prob_rev = 0

    if tokenised_hashtag != tokenised_hashtag_rev:

        idx += 1
        print(str(idx)+".", hashtag)

        for token in tokenised_hashtag:
            if token in word_freq:
                log_prob += math.log(word_freq[token]/word_total)
            else:
                log_prob += math.log(1/word_total)
            
        print("MaxMatch =", tokenised_hashtag, ";", "LogProb =", log_prob)

        for token in tokenised_hashtag_rev:
            if token in word_freq:
                log_prob_rev += math.log(word_freq[token]/word_total)
            else:
                log_prob_rev += math.log(1/word_total)

        print("Reversed MaxMatch =", tokenised_hashtag_rev, ";", "LogProb =", log_prob_rev)
   
    
###
# Your answer ENDS HERE
###
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\lhg45\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 1. #asksteven
# MaxMatch = ['asks', 'te', 'v', 'en'] ; LogProb = -47.727711713780785
# Reversed MaxMatch = ['ask', 'steven'] ; LogProb = -23.077884979448676
# 2. #wearesocial
# MaxMatch = ['weares', 'o', 'c', 'i', 'al'] ; LogProb = -50.00255844796777
# Reversed MaxMatch = ['we', 'are', 'social'] ; LogProb = -19.6836370080817
# 3. #usydhereicome
# MaxMatch = ['us', 'y', 'd', 'here', 'i', 'come'] ; LogProb = -50.13831234348764
# Reversed MaxMatch = ['u', 'syd', 'here', 'i', 'come'] ; LogProb = -45.64457897307673
# 4. #reachingyougpeople
# MaxMatch = ['reaching', 'you', 'g', 'people'] ; LogProb = -34.486914655553974
# Reversed MaxMatch = ['reaching', 'yo', 'ug', 'people'] ; LogProb = -45.35692967639097
# 5. #laundryservice
# MaxMatch = ['laundrys', 'er', 'vice'] ; LogProb = -38.18130079834813
# Reversed MaxMatch = ['laundry', 'service'] ; LogProb = -20.56790469210856
# 6. #ariona
# MaxMatch = ['arion', 'a'] ; LogProb = -17.87822322618245
# Reversed MaxMatch = ['ar', 'i', 'ona'] ; LogProb = -33.3454061130859
# 7. #burgers
# MaxMatch = ['burg', 'ers'] ; LogProb = -27.929915243368292
# Reversed MaxMatch = ['bur', 'gers'] ; LogProb = -27.929915243368292
# 8. #cornell
# MaxMatch = ['cornel', 'l'] ; LogProb = -25.15732652112851
# Reversed MaxMatch = ['cor', 'nell'] ; LogProb = -27.929915243368292
# 9. #peperoni
# MaxMatch = ['pep', 'er', 'on', 'i'] ; LogProb = -38.49440017391662
# Reversed MaxMatch = ['pep', 'e', 'ro', 'ni'] ; LogProb = -52.17095103262265
# 10. #hb60
# MaxMatch = ['h', 'b'] ; LogProb = -20.14046067728162
# Reversed MaxMatch = [] ; LogProb = 0
# 11. #1yearofalmostisneverenough
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['year', 'of', 'al', 'mos', 'tis', 'never', 'enough'] ; LogProb = -64.9333983065222
# 12. #longranger
# MaxMatch = ['long', 'ranger'] ; LogProb = -20.614031738858507
# Reversed MaxMatch = ['l', 'on', 'granger'] ; LogProb = -30.30632058195922
# 13. #ahimacon14
# MaxMatch = ['ah', 'ima', 'con'] ; LogProb = -36.85792026263881
# Reversed MaxMatch = [] ; LogProb = 0
# 14. #election2015
# MaxMatch = ['election'] ; LogProb = -9.621152199830464
# Reversed MaxMatch = [] ; LogProb = 0
# 15. #askolly
# MaxMatch = ['ask', 'o', 'l', 'ly'] ; LogProb = -44.9771149625557
# Reversed MaxMatch = ['as', 'kol', 'ly'] ; LogProb = -33.00570240968902
# 16. #booyaa
# MaxMatch = ['boo', 'ya', 'a'] ; LogProb = -30.456886486746704
# Reversed MaxMatch = ['boo', 'y', 'aa'] ; LogProb = -40.28543495261834
# 17. #insightmediasingapore
# MaxMatch = ['insight', 'media', 'sing', 'a', 'pore'] ; LogProb = -49.89759657523893
# Reversed MaxMatch = ['insight', 'me', 'di', 'as', 'inga', 'pore'] ; LogProb = -60.95122637126752
# 18. #excitables
# MaxMatch = ['excitable', 's'] ; LogProb = -24.838872790009976
# Reversed MaxMatch = ['ex', 'c', 'i', 'tables'] ; LogProb = -38.03723637469511
# 19. #fotografías
# MaxMatch = ['fot', 'og', 'ra', 'f'] ; LogProb = -52.276311548280475
# Reversed MaxMatch = ['as'] ; LogProb = -5.075787166320734
# 20. #makeupfree
# MaxMatch = ['make', 'up', 'free'] ; LogProb = -22.116629234052077
# Reversed MaxMatch = ['ma', 'keup', 'free'] ; LogProb = -33.39360582418646
# 21. #ladygaga
# MaxMatch = ['lady', 'gag', 'a'] ; LogProb = -26.074859852072823
# Reversed MaxMatch = ['lady', 'g', 'aga'] ; LogProb = -34.74025750813878
# 22. #blessedmorethanicanimagine
# MaxMatch = ['blessed', 'more', 'than', 'i', 'can', 'imagine'] ; LogProb = -45.89161304402444
# Reversed MaxMatch = ['blessed', 'more', 'th', 'ani', 'can', 'imagine'] ; LogProb = -61.237903514265824
# 23. #vegan
# MaxMatch = ['vega', 'n'] ; LogProb = -24.292329083641906
# Reversed MaxMatch = ['v', 'e', 'gan'] ; LogProb = -34.91015654493417
# 24. #electriccircus2014
# MaxMatch = ['electric', 'circus'] ; LogProb = -21.76449738913687
# Reversed MaxMatch = [] ; LogProb = 0
# 25. #skeemsaam
# MaxMatch = ['skee', 'ms', 'aam'] ; LogProb = -41.20172568449249
# Reversed MaxMatch = ['s', 'k', 'e', 'ems', 'aam'] ; LogProb = -60.74228110795444
# 26. #magazinesandtvscreens
# MaxMatch = ['magazines', 'and', 't', 'vs', 'creen', 's'] ; LogProb = -61.47975841623954
# Reversed MaxMatch = ['magazine', 'sand', 't', 'v', 'screens'] ; LogProb = -52.88679457126382
# 27. #statoftheday
# MaxMatch = ['st', 'at', 'oft', 'he', 'day'] ; LogProb = -45.53941127109653
# Reversed MaxMatch = ['s', 'tat', 'of', 'the', 'day'] ; LogProb = -38.54292154373771
# 28. #thenext5goldenyears
# MaxMatch = ['then', 'ex', 't'] ; LogProb = -29.62808148448756
# Reversed MaxMatch = ['golden', 'years'] ; LogProb = -17.335783640490337
# 29. #olah
# MaxMatch = ['o', 'la', 'h'] ; LogProb = -31.55003839252038
# Reversed MaxMatch = ['o', 'l', 'ah'] ; LogProb = -32.77314515143286
# 30. #affsuzukicup
# MaxMatch = ['a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup'] ; LogProb = -90.6513566774273
# Reversed MaxMatch = ['a', 'f', 'f', 'suz', 'u', 'k', 'i', 'cup'] ; LogProb = -77.27726738718268
# 31. #5sosfam
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['sos', 'fam'] ; LogProb = -27.929915243368292
# 32. #strictlyus
# MaxMatch = ['strictly', 'us'] ; LogProb = -17.918694991029284
# Reversed MaxMatch = ['strict', 'l', 'yus'] ; LogProb = -36.72438887001429
# 33. #bradersisterhood
# MaxMatch = ['brad', 'ers', 'ist', 'er', 'hood'] ; LogProb = -67.87887795936541
# Reversed MaxMatch = ['brad', 'er', 'sisterhood'] ; LogProb = -41.894872865052434
# 34. #uniexamonasaturday
# MaxMatch = ['unie', 'x', 'am', 'ona', 'saturday'] ; LogProb = -57.44398514679243
# Reversed MaxMatch = ['u', 'ni', 'ex', 'a', 'mona', 'saturday'] ; LogProb = -66.27526455550658
# 35. #askherforfback
# MaxMatch = ['ask', 'her', 'for', 'f', 'back'] ; LogProb = -37.339890421343206
# Reversed MaxMatch = ['ask', 'her', 'f', 'orf', 'back'] ; LogProb = -46.497778933316965
# 36. #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me'] ; LogProb = -129.3969380184581
# Reversed MaxMatch = ['i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme'] ; LogProb = -81.54186163845988
# 37. #southampton
# MaxMatch = ['south', 'am', 'p', 'ton'] ; LogProb = -38.0154487245116
# Reversed MaxMatch = ['s', 'out', 'ham', 'p', 'ton'] ; LogProb = -49.24536094724618
# 38. #thankyoulord
# MaxMatch = ['thank', 'youl', 'or', 'd'] ; LogProb = -40.02002118658969
# Reversed MaxMatch = ['thank', 'you', 'lord'] ; LogProb = -25.681328134845863
# 39. #ciosummit
# MaxMatch = ['c', 'ios', 'um', 'mi', 't'] ; LogProb = -58.200285491182306
# Reversed MaxMatch = ['c', 'io', 'summit'] ; LogProb = -34.6141756696677
# 40. #thecolorrun2014
# MaxMatch = ['the', 'color', 'run'] ; LogProb = -20.44080801829395
# Reversed MaxMatch = [] ; LogProb = 0
# 41. #thewalkingdead
# MaxMatch = ['thew', 'alk', 'ing', 'dead'] ; LogProb = -50.700775187522055
# Reversed MaxMatch = ['the', 'walking', 'dead'] ; LogProb = -21.59099736979646
# 42. #innoretail
# MaxMatch = ['inn', 'ore', 'tail'] ; LogProb = -36.51959445736827
# Reversed MaxMatch = ['in', 'no', 'retail'] ; LogProb = -21.26284894851116
# 43. #focusateneo
# MaxMatch = ['focus', 'aten', 'e', 'o'] ; LogProb = -45.22397504048723
# Reversed MaxMatch = ['fo', 'c', 'u', 'sate', 'neo'] ; LogProb = -62.46404820536246
# 44. #datingsiteforyou
# MaxMatch = ['datings', 'it', 'e', 'for', 'you'] ; LogProb = -39.80264265980539
# Reversed MaxMatch = ['dating', 'site', 'for', 'you'] ; LogProb = -33.059338231686056
# 45. #getfreetattooaviciipasses
# MaxMatch = ['get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb = -71.9179339033951
# Reversed MaxMatch = ['get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb = -67.71133718001329
# 46. #toronto
# MaxMatch = ['toro', 'n', 'to'] ; LogProb = -28.085376355276956
# Reversed MaxMatch = ['tor', 'onto'] ; LogProb = -23.835570681146194
# 47. #blackhat
# MaxMatch = ['black', 'hat'] ; LogProb = -18.59135757359136
# Reversed MaxMatch = ['b', 'lac', 'khat'] ; LogProb = -37.240912514894916
# 48. #thevoiceau
# MaxMatch = ['the', 'voice', 'a', 'u'] ; LogProb = -26.666817963339746
# Reversed MaxMatch = ['the', 'v', 'o', 'i', 'c', 'ea', 'u'] ; LogProb = -64.13472714326123
# 49. #takeabreak
# MaxMatch = ['take', 'ab', 'reak'] ; LogProb = -34.38280161921698
# Reversed MaxMatch = ['ta', 'kea', 'break'] ; LogProb = -37.417536050574235
# 50. #pmattheashes
# MaxMatch = ['p', 'matt', 'he', 'ashes'] ; LogProb = -39.47463840109537
# Reversed MaxMatch = ['p', 'mat', 'the', 'ashes'] ; LogProb = -36.97206361531092
# 51. #coffeespoonart
# MaxMatch = ['coffees', 'poon', 'art'] ; LogProb = -36.55733478535112
# Reversed MaxMatch = ['coffee', 'spoon', 'art'] ; LogProb = -30.408866489433475
# 52. #txlege
# MaxMatch = ['t', 'x', 'leg', 'e'] ; LogProb = -41.05865239912034
# Reversed MaxMatch = ['t', 'x', 'l', 'e', 'ge'] ; LogProb = -55.61831712855118
# 53. #google
# MaxMatch = ['goo', 'g', 'l', 'e'] ; LogProb = -46.62577358814309
# Reversed MaxMatch = ['go', 'ogle'] ; LogProb = -21.490564872268195
# 54. #mtlnewtech
# MaxMatch = ['m', 't', 'l', 'newt', 'e', 'c', 'h'] ; LogProb = -74.16611472813612
# Reversed MaxMatch = ['m', 't', 'l', 'new', 'tech'] ; LogProb = -50.45696561707631
# 55. #yws13
# MaxMatch = ['y', 'ws'] ; LogProb = -26.320477330934192
# Reversed MaxMatch = [] ; LogProb = 0
# 56. #isibaya
# MaxMatch = ['is', 'iba', 'ya'] ; LogProb = -31.287397108778492
# Reversed MaxMatch = ['i', 'si', 'baya'] ; LogProb = -33.3454061130859
# 57. #notersnew2014
# MaxMatch = ['noter', 'snew'] ; LogProb = -27.929915243368292
# Reversed MaxMatch = [] ; LogProb = 0
# 58. #instalook
# MaxMatch = ['ins', 'tal', 'o', 'ok'] ; LogProb = -50.992296036281004
# Reversed MaxMatch = ['ins', 'ta', 'look'] ; LogProb = -35.90591144816258
# 59. #swedumtl
# MaxMatch = ['s', 'wed', 'um', 't', 'l'] ; LogProb = -57.53790996928912
# Reversed MaxMatch = ['s', 'we', 'dum', 't', 'l'] ; LogProb = -51.7342821596632
# 60. #grammyfans
# MaxMatch = ['gram', 'my', 'fans'] ; LogProb = -29.363894619272518
# Reversed MaxMatch = ['g', 'rammy', 'fans'] ; LogProb = -36.07776170508923
# 61. #surfshop
# MaxMatch = ['surfs', 'hop'] ; LogProb = -27.236768062808345
# Reversed MaxMatch = ['surf', 'shop'] ; LogProb = -23.786780516976762
# 62. #loadsoffun
# MaxMatch = ['loads', 'off', 'un'] ; LogProb = -30.567433960219322
# Reversed MaxMatch = ['loads', 'of', 'fun'] ; LogProb = -25.305444468514956
# 63. #learningcommunties
# MaxMatch = ['learning', 'c', 'om', 'munt', 'ies'] ; LogProb = -60.9346530006019
# Reversed MaxMatch = ['learning', 'c', 'om', 'm', 'unties'] ; LogProb = -58.16206427836211
# 64. #goingout
# MaxMatch = ['going', 'out'] ; LogProb = -14.29269079557651
# Reversed MaxMatch = ['go', 'in', 'gout'] ; LogProb = -24.79417737948751
# 65. #shopaholic
# MaxMatch = ['shop', 'aho', 'li', 'c'] ; LogProb = -46.920905214748316
# Reversed MaxMatch = ['sho', 'paho', 'li', 'c'] ; LogProb = -51.06403994113984
# 66. #skullsearcher
# MaxMatch = ['skulls', 'ear', 'che', 'r'] ; LogProb = -48.16180131646378
# Reversed MaxMatch = ['skull', 'searcher'] ; LogProb = -26.831302954700185
# 67. #brooksengland
# MaxMatch = ['brooks', 'en', 'gland'] ; LogProb = -34.97914941642112
# Reversed MaxMatch = ['brook', 'sen', 'gland'] ; LogProb = -38.59903599904811
# 68. #flambees
# MaxMatch = ['flamb', 'e', 'es'] ; LogProb = -38.205993410938504
# Reversed MaxMatch = ['flam', 'bees'] ; LogProb = -25.22186504226608
# 69. #veganfood
# MaxMatch = ['vega', 'n', 'food'] ; LogProb = -33.266854118547315
# Reversed MaxMatch = ['v', 'e', 'gan', 'food'] ; LogProb = -43.88468157983958
# 70. #nced
# MaxMatch = ['n', 'ce', 'd'] ; LogProb = -34.345263699897906
# Reversed MaxMatch = ['n', 'c', 'ed'] ; LogProb = -30.896546802267775
# 71. #weare90s
# MaxMatch = ['wear', 'e'] ; LogProb = -20.685687727764943
# Reversed MaxMatch = ['s'] ; LogProb = -10.87391516832583
# 72. #imsobored
# MaxMatch = ['i', 'ms', 'o', 'bored'] ; LogProb = -40.720062686573364
# Reversed MaxMatch = ['i', 'm', 'so', 'bored'] ; LogProb = -34.30534348979372
# 73. #foodporn
# MaxMatch = ['food', 'po', 'r', 'n'] ; LogProb = -43.594225580505075
# Reversed MaxMatch = ['food', 'p', 'or', 'n'] ; LogProb = -34.55681104368249
# 74. #startupfest
# MaxMatch = ['start', 'up', 'fest'] ; LogProb = -29.313588154585123
# Reversed MaxMatch = ['star', 'tup', 'fest'] ; LogProb = -38.67599704018424
# 75. #1stsundayofoctober
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['st', 'sunday', 'of', 'october'] ; LogProb = -36.810230667545824
# 76. #endomondo
# MaxMatch = ['end', 'om', 'on', 'do'] ; LogProb = -33.812708338143814
# Reversed MaxMatch = ['en', 'do', 'mon', 'do'] ; LogProb = -39.4790334742882
# 77. #butitsalsokindofaphone
# MaxMatch = ['but', 'its', 'also', 'kind', 'of', 'a', 'phone'] ; LogProb = -44.57840330966084
# Reversed MaxMatch = ['bu', 'tits', 'also', 'kin', 'do', 'fa', 'phone'] ; LogProb = -78.18750260138327
# 78. #rainorshine
# MaxMatch = ['rain', 'ors', 'hin', 'e'] ; LogProb = -47.92245579057329
# Reversed MaxMatch = ['r', 'ai', 'nor', 'shine'] ; LogProb = -45.33980685601235
# 79. #aim20
# MaxMatch = ['aim'] ; LogProb = -10.354039709039922
# Reversed MaxMatch = [] ; LogProb = 0
# 80. #photoby
# MaxMatch = ['photo', 'by'] ; LogProb = -17.74388379623651
# Reversed MaxMatch = ['pho', 'toby'] ; LogProb = -27.929915243368292
# 81. #365picture
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['picture'] ; LogProb = -8.877361286451762
# 82. #potd
# MaxMatch = ['pot', 'd'] ; LogProb = -20.685687727764943
# Reversed MaxMatch = ['po', 'td'] ; LogProb = -27.929915243368292
# 83. #fotorus
# MaxMatch = ['fot', 'or', 'us'] ; LogProb = -27.035892817917265
# Reversed MaxMatch = ['fo', 'torus'] ; LogProb = -27.929915243368292
# 84. #difd
# MaxMatch = ['di', 'f', 'd'] ; LogProb = -31.308288467809867
# Reversed MaxMatch = ['d', 'if', 'd'] ; LogProb = -26.375523719232582
# 85. #mwc14
# MaxMatch = ['m', 'w', 'c'] ; LogProb = -32.71705568478182
# Reversed MaxMatch = [] ; LogProb = 0
# 86. #scifigeek
# MaxMatch = ['s', 'c', 'if', 'i', 'geek'] ; LogProb = -45.693185222535575
# Reversed MaxMatch = ['s', 'c', 'i', 'fi', 'geek'] ; LogProb = -53.38848835749914
# 87. #pop-up
# MaxMatch = ['pop'] ; LogProb = -12.019047472628833
# Reversed MaxMatch = ['up'] ; LogProb = -6.420625513630458
# 88. #hometomama
# MaxMatch = ['home', 'toma', 'ma'] ; LogProb = -32.64598508346402
# Reversed MaxMatch = ['home', 'tom', 'ama'] ; LogProb = -31.447289336238928
# 89. #thankyoupatients
# MaxMatch = ['thank', 'youp', 'ati', 'en', 'ts'] ; LogProb = -64.2953590209093
# Reversed MaxMatch = ['thank', 'you', 'patients'] ; LogProb = -26.630408689543007
# 90. #oilandgas
# MaxMatch = ['oil', 'and', 'gas'] ; LogProb = -22.475906870652068
# Reversed MaxMatch = ['o', 'i', 'land', 'gas'] ; LogProb = -34.072652283824894
# 91. #anferneehardaway
# MaxMatch = ['an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay'] ; LogProb = -83.75954146558668
# Reversed MaxMatch = ['an', 'f', 'er', 'nee', 'hard', 'away'] ; LogProb = -60.548625394324596
# 92. #pechanga
# MaxMatch = ['pech', 'an', 'ga'] ; LogProb = -33.66803197464386
# Reversed MaxMatch = ['p', 'e', 'changa'] ; LogProb = -33.875260070652175
# 93. #myfriendsarebetterthanyours
# MaxMatch = ['my', 'friends', 'are', 'better', 'than', 'yours'] ; LogProb = -46.395570729337166
# Reversed MaxMatch = ['my', 'friend', 'sare', 'better', 'than', 'yours'] ; LogProb = -54.98081318929236
# 94. #stampede2014
# MaxMatch = ['stampede'] ; LogProb = -12.578663260564255
# Reversed MaxMatch = [] ; LogProb = 0
# 95. #tcschleissheim
# MaxMatch = ['t', 'cs', 'c', 'h', 'leis', 'she', 'i', 'm'] ; LogProb = -80.16393841207338
# Reversed MaxMatch = ['t', 'cs', 'c', 'h', 'lei', 'ss', 'hei', 'm'] ; LogProb = -95.28568770673392
# 96. #bringithomemy
# MaxMatch = ['bring', 'it', 'home', 'my'] ; LogProb = -28.23096475229475
# Reversed MaxMatch = ['brin', 'git', 'home', 'my'] ; LogProb = -40.98521660813226
# 97. #grandmarnier
# MaxMatch = ['grandma', 'r', 'ni', 'er'] ; LogProb = -49.65729496954866
# Reversed MaxMatch = ['grand', 'm', 'arni', 'er'] ; LogProb = -49.21604075358891
# 98. #2littlebirds
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['little', 'birds'] ; LogProb = -17.164234180678296
# 99. #ritenow
# MaxMatch = ['rite', 'now'] ; LogProb = -18.669642502643903
# Reversed MaxMatch = ['rit', 'enow'] ; LogProb = -27.929915243368292
# 100. #worldcup2014
# MaxMatch = ['world', 'cup'] ; LogProb = -17.45502450518057
# Reversed MaxMatch = [] ; LogProb = 0
# 101. #startuphub
# MaxMatch = ['start', 'up', 'hub'] ; LogProb = -26.915692881786754
# Reversed MaxMatch = ['star', 'tup', 'hub'] ; LogProb = -36.27810176738587
# 102. #letmesleep
# MaxMatch = ['let', 'mes', 'leep'] ; LogProb = -35.94423031246471
# Reversed MaxMatch = ['let', 'me', 'sleep'] ; LogProb = -24.695726226371715
# 103. #cumannanya
# MaxMatch = ['cum', 'anna', 'n', 'ya'] ; LogProb = -48.89003981683499
# Reversed MaxMatch = ['c', 'u', 'mannan', 'ya'] ; LogProb = -47.112796222558416
# 104. #2015eebritishfilmacademyawards
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['e', 'e', 'british', 'film', 'academy', 'awards'] ; LogProb = -61.06568683153934
# 105. #5sosacousticatlanta
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['sos', 'acoustic', 'atlanta'] ; LogProb = -38.33952480356302
# 106. #alliswell
# MaxMatch = ['all', 'is', 'well'] ; LogProb = -17.867934762399223
# Reversed MaxMatch = ['al', 'li', 'swell'] ; LogProb = -36.73008689112893
# 107. #usydoweek
# MaxMatch = ['us', 'y', 'dow', 'e', 'e', 'k'] ; LogProb = -64.59895676445645
# Reversed MaxMatch = ['us', 'y', 'do', 'week'] ; LogProb = -34.90146535406686
# 108. #imsosore
# MaxMatch = ['i', 'ms', 'os', 'ore'] ; LogProb = -46.6172165542101
# Reversed MaxMatch = ['i', 'm', 'so', 'sore'] ; LogProb = -34.64181572641493
# 109. #samsung
# MaxMatch = ['sams', 'un', 'g'] ; LogProb = -36.557334785351124
# Reversed MaxMatch = ['sam', 'sung'] ; LogProb = -20.670095633005108
# 110. #singapore
# MaxMatch = ['sing', 'a', 'pore'] ; LogProb = -27.62367314269049
# Reversed MaxMatch = ['s', 'inga', 'pore'] ; LogProb = -38.110683231134175
# 111. #yiamas
# MaxMatch = ['y', 'i', 'ama', 's'] ; LogProb = -42.609883368977634
# Reversed MaxMatch = ['y', 'i', 'a', 'mas'] ; LogProb = -35.64923380515011
# 112. #lebedeintennis
# MaxMatch = ['l', 'e', 'bed', 'e', 'in', 'tennis'] ; LogProb = -56.118962878171544
# Reversed MaxMatch = ['l', 'e', 'be', 'de', 'in', 'tennis'] ; LogProb = -51.08755532769554
# 113. #harimaumalaya
# MaxMatch = ['ha', 'rima', 'um', 'ala', 'ya'] ; LogProb = -66.359052205621
# Reversed MaxMatch = ['h', 'ar', 'i', 'mau', 'mala', 'ya'] ; LogProb = -70.71849040108931
# 114. #blogtourambiente
# MaxMatch = ['blo', 'g', 'tour', 'ambient', 'e'] ; LogProb = -59.60211981637345
# Reversed MaxMatch = ['b', 'log', 'tou', 'ram', 'bien', 'te'] ; LogProb = -76.04474292658905
# 115. #cleansidewalk
# MaxMatch = ['cleans', 'ide', 'walk'] ; LogProb = -37.28970267906435
# Reversed MaxMatch = ['clean', 'sidewalk'] ; LogProb = -20.651286301047612
# 116. #happybirthdaysandarapark
# MaxMatch = ['happy', 'birthdays', 'anda', 'rap', 'ark'] ; LogProb = -64.54667344919022
# Reversed MaxMatch = ['happy', 'birthday', 'sand', 'ara', 'park'] ; LogProb = -54.473949579408796
# 117. #100percentpay
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['percent', 'pay'] ; LogProb = -18.81212885300272
# 118. #meetup
# MaxMatch = ['meet', 'up'] ; LogProb = -15.381636829369146
# Reversed MaxMatch = ['me', 'e', 'tup'] ; LogProb = -31.13187659474114
# 119. #8thannualpubcrawl
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['th', 'annual', 'pub', 'crawl'] ; LogProb = -48.929335720784955
# 120. #cdnpoli
# MaxMatch = ['c', 'd', 'n', 'pol', 'i'] ; LogProb = -48.92992164570293
# Reversed MaxMatch = ['c', 'd', 'n', 'po', 'li'] ; LogProb = -57.47938839766947
# 121. #arte
# MaxMatch = ['art', 'e'] ; LogProb = -18.903497709553037
# Reversed MaxMatch = ['ar', 'te'] ; LogProb = -27.929915243368292
# 122. #uptonogood
# MaxMatch = ['up', 'ton', 'og', 'o', 'od'] ; LogProb = -56.45741010488402
# Reversed MaxMatch = ['up', 'to', 'no', 'good'] ; LogProb = -23.783410577044766
# 123. #openspace
# MaxMatch = ['opens', 'pace'] ; LogProb = -21.39612640543495
# Reversed MaxMatch = ['open', 'space'] ; LogProb = -16.95292810297913
# 124. #jordaan
# MaxMatch = ['jo', 'r', 'da', 'an'] ; LogProb = -39.495593766271355
# Reversed MaxMatch = ['j', 'or', 'da', 'an'] ; LogProb = -34.788912569735096
# 125. #palacefansinthemorning
# MaxMatch = ['palace', 'fans', 'in', 'them', 'or', 'ning'] ; LogProb = -51.306318886754084
# Reversed MaxMatch = ['palace', 'fan', 'sin', 'the', 'morning'] ; LogProb = -42.81884399429282
# 126. #beringmy
# MaxMatch = ['beri', 'n', 'g', 'my'] ; LogProb = -42.265784889707966
# Reversed MaxMatch = ['be', 'ring', 'my'] ; LogProb = -22.100401501964658
# 127. #seniorbabysenior
# MaxMatch = ['senior', 'babys', 'en', 'io', 'r'] ; LogProb = -60.71493127502287
# Reversed MaxMatch = ['senior', 'baby', 'senior'] ; LogProb = -30.715017430775028
# 128. #melbourne
# MaxMatch = ['mel', 'bourn', 'e'] ; LogProb = -36.12655186925867
# Reversed MaxMatch = ['m', 'elb', 'our', 'ne'] ; LogProb = -44.1629847436087
# 129. #siberuang
# MaxMatch = ['sib', 'er', 'uang'] ; LogProb = -41.894872865052434
# Reversed MaxMatch = ['si', 'ber', 'uang'] ; LogProb = -41.894872865052434
# 130. #bettybooppose
# MaxMatch = ['betty', 'boo', 'p', 'pose'] ; LogProb = -48.032589584983775
# Reversed MaxMatch = ['betty', 'bo', 'oppose'] ; LogProb = -38.088210375282124
# 131. #nickryrie
# MaxMatch = ['nick', 'r', 'yr', 'ie'] ; LogProb = -49.003368502141996
# Reversed MaxMatch = ['nick', 'r', 'y', 'rie'] ; LogProb = -47.39393058970791
# 132. #mamajeanneandme
# MaxMatch = ['mam', 'a', 'jeanne', 'and', 'me'] ; LogProb = -42.42901002237228
# Reversed MaxMatch = ['m', 'ama', 'jeanne', 'and', 'me'] ; LogProb = -49.70811331731834
# 133. #vscocam
# MaxMatch = ['vs', 'coca', 'm'] ; LogProb = -37.735989781692766
# Reversed MaxMatch = ['vs', 'c', 'o', 'cam'] ; LogProb = -46.41964904199847
# 134. #2011prdctn
# MaxMatch = [] ; LogProb = 0
# Reversed MaxMatch = ['p', 'r', 'd', 'c', 't', 'n'] ; LogProb = -59.132221097487204
# 135. #allwedoiscurls
# MaxMatch = ['all', 'wed', 'o', 'is', 'curls'] ; LogProb = -48.645662149244885
# Reversed MaxMatch = ['all', 'w', 'edo', 'is', 'curls'] ; LogProb = -50.987467955392205
# 136. #socal
# MaxMatch = ['soc', 'al'] ; LogProb = -24.711039418500093
# Reversed MaxMatch = ['so', 'cal'] ; LogProb = -20.336541050247
# 137. #jrsurfboards
# MaxMatch = ['j', 'rs', 'urf', 'boards'] ; LogProb = -50.21792341579847
# Reversed MaxMatch = ['j', 'r', 'surfboards'] ; LogProb = -36.465527236098
# 138. #instagood
# MaxMatch = ['ins', 'tag', 'o', 'od'] ; LogProb = -50.992296036281004
# Reversed MaxMatch = ['ins', 'ta', 'good'] ; LogProb = -35.20278912254581
# 139. #nevergetsold
# MaxMatch = ['never', 'gets', 'old'] ; LogProb = -24.664678872413806
# Reversed MaxMatch = ['never', 'get', 'sold'] ; LogProb = -24.87920086906464
# 140. #danny4mayor
# MaxMatch = ['danny'] ; LogProb = -12.173198152456091
# Reversed MaxMatch = ['mayor'] ; LogProb = -10.32737146195776
# 141. #wok
# MaxMatch = ['wo', 'k'] ; LogProb = -25.62733015037425
# Reversed MaxMatch = ['w', 'ok'] ; LogProb = -24.711039418500093
# 142. #bedimages
# MaxMatch = ['bedim', 'ages'] ; LogProb = -23.998089610643966
# Reversed MaxMatch = ['bed', 'images'] ; LogProb = -19.474810244265477
# 143. #cbcolympics
# MaxMatch = ['c', 'b', 'coly', 'm', 'pics'] ; LogProb = -57.60244849042668
# Reversed MaxMatch = ['c', 'b', 'col', 'ym', 'pics'] ; LogProb = -60.37503721266647

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

###
# Your answer BEGINS HERE
###

x_train, x_test, y_train, y_test = train_test_split(x_processed, y_processed, train_size=0.7, test_size=0.3, random_state=888, stratify=y_processed)
x_dev, x_test, y_dev, y_test = train_test_split(x_test, y_test, train_size=0.5, test_size=0.5, random_state=888, stratify=y_test)

vectorizer = DictVectorizer(sparse=False)
x_train = vectorizer.fit_transform(x_train)
x_dev = vectorizer.transform(x_dev)
x_test = vectorizer.transform(x_test)

###
# Your answer ENDS HERE
###

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output. Your code should not take more than 1 minute to run (or penalty applies).
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import numpy as np

###
# Your answer BEGINS HERE
###

Best_a = 0
Best_NBscore = 0
A = [0.05 * i for i in range(1, 20)]

for a in A: 
    NB_classifier = MultinomialNB(alpha=a)
    NB_classifier.fit(x_train, y_train)
    
    if NB_classifier.score(x_dev, y_dev) > Best_NBscore:
        Best_NBscore = NB_classifier.score(x_dev, y_dev)
        Best_a = a
        best_NB_classifier = NB_classifier

    print("The Naive Bayes accuracy", NB_classifier.score(x_dev, y_dev), "with alpha =", a)

Best_c = 0
Best_LRscore = 0

C = [0.25 * i for i in range(1, 40)]
for c in C:
    LR_classifier = LogisticRegression(penalty='l2', solver='lbfgs',C = c, max_iter=888)
    LR_classifier.fit(x_train, y_train)

    if LR_classifier.score(x_dev, y_dev) > Best_LRscore:
        Best_LRscore = LR_classifier.score(x_dev, y_dev)
        Best_c = c
        best_LR_classifier = LR_classifier

    print("The Logistic Regressions accuracy", LR_classifier.score(x_dev, y_dev), "with regularization strength =", c)

###
# Your answer ENDS HERE
###
# Out:
# The Naive Bayes accuracy 0.2907801418439716 with alpha = 0.05
# The Naive Bayes accuracy 0.2907801418439716 with alpha = 0.1
# The Naive Bayes accuracy 0.2978723404255319 with alpha = 0.15000000000000002
# The Naive Bayes accuracy 0.2978723404255319 with alpha = 0.2
# The Naive Bayes accuracy 0.2978723404255319 with alpha = 0.25
# The Naive Bayes accuracy 0.2978723404255319 with alpha = 0.30000000000000004
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.35000000000000003
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.4
# The Naive Bayes accuracy 0.3120567375886525 with alpha = 0.45
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.5
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.55
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.6000000000000001
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.65
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.7000000000000001
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.75
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.8
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.8500000000000001
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.9
# The Naive Bayes accuracy 0.3049645390070922 with alpha = 0.9500000000000001
# The Logistic Regressions accuracy 0.3049645390070922 with regularization strength = 0.25
# The Logistic Regressions accuracy 0.3049645390070922 with regularization strength = 0.5
# The Logistic Regressions accuracy 0.3049645390070922 with regularization strength = 0.75
# The Logistic Regressions accuracy 0.2978723404255319 with regularization strength = 1.0
# The Logistic Regressions accuracy 0.2978723404255319 with regularization strength = 1.25
# The Logistic Regressions accuracy 0.3049645390070922 with regularization strength = 1.5
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 1.75
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 2.0
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 2.25
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 2.5
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 2.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 3.0
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 3.25
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 3.5
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 3.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 4.0
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 4.25
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 4.5
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 4.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 5.0
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 5.25
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 5.5
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 5.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 6.0
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 6.25
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 6.5
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 6.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 7.0
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 7.25
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 7.5
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 7.75
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 8.0
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 8.25
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 8.5
# The Logistic Regressions accuracy 0.3120567375886525 with regularization strength = 8.75
# The Logistic Regressions accuracy 0.3191489361702128 with regularization strength = 9.0
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 9.25
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 9.5
# The Logistic Regressions accuracy 0.3262411347517731 with regularization strength = 9.75

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
from sklearn.metrics import accuracy_score, f1_score
###
# Your answer BEGINS HERE
###

y_predict_NB = best_NB_classifier.predict(x_test)
y_predict_LR = best_LR_classifier.predict(x_test)

#LR_classifier = LogisticRegression(penalty='l2', solver='lbfgs',C = c, max_iter=100)

print("The best Naive Bayes accuracy", accuracy_score(y_test, y_predict_NB))
print("The best Naive Bayes F-score", f1_score(y_test, y_predict_NB, average='macro'))
print("The best Logistic Regressions accuracy", accuracy_score(y_test, y_predict_LR))
print("The best Logistic Regressions F-score", f1_score(y_test, y_predict_LR, average='macro'))

###
# Your answer ENDS HERE
###
# Out:
# The best Naive Bayes accuracy 0.2887323943661972
# The best Naive Bayes F-score 0.2902032428571095
# The best Logistic Regressions accuracy 0.2887323943661972
# The best Logistic Regressions F-score 0.2877451858486341

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###
#import numpy as np
#import pandas as pd

print("Classifier = Naive Bayes ")
print('\n')

def format_printing(dict):
    for country_code, token in dict.items():
        print(f"Country = {country_code}")
        for idx, (token, score) in enumerate(token.items()):
            if idx >= 20:
                print("")
                print("")
                break
            print(f"{token} ({score:.3f}) ", end=' ')


NB_dict = {}

for i in range(len(best_NB_classifier.classes_)):
    NB_dict[best_NB_classifier.classes_[i]] = {}
    for j in range(len(vectorizer.feature_names_)):
        NB_dict[best_NB_classifier.classes_[i]][vectorizer.feature_names_[j]] = best_NB_classifier.feature_log_prob_[i][j]

NB_dict_sorted = {
    Class: dict(sorted(sub_dict.items(), key=lambda item: item[1], reverse=True))
    for Class, sub_dict in NB_dict.items()
}

format_printing(NB_dict_sorted)


print("Classifier = Logistic Regression ")
print('\n')

LR_dict = {}

for i in range(len(best_LR_classifier.classes_)):
    LR_dict[best_LR_classifier.classes_[i]] = {}
    for j in range(len(vectorizer.feature_names_)):
        LR_dict[best_LR_classifier.classes_[i]][vectorizer.feature_names_[j]] = best_LR_classifier.coef_[i][j]

LR_dict_sorted = {
    Class: dict(sorted(sub_dict.items(), key=lambda item: item[1], reverse=True))
    for Class, sub_dict in LR_dict.items()
}

format_printing(LR_dict_sorted)


###
# Your answer ENDS HERE
###
# Out:
# Classifier = Naive Bayes
#
#
# Country = au
# australia (-5.919)  great (-5.919)  one (-5.919)  even (-6.121)  love (-6.376)  melbourne (-6.376)  #affsuzukicup (-6.718)  #mtvhottest (-6.718)  @micksunnyg (-6.718)  already (-6.718)  australian (-6.718)  away (-6.718)  awesome (-6.718)  big (-6.718)  come (-6.718)  direction (-6.718)  end (-6.718)  family (-6.718)  follow (-6.718)  go (-6.718)
#
# Country = ca
# like (-5.937)  first (-6.140)  good (-6.140)  got (-6.140)  great (-6.140)  maybe (-6.140)  right (-6.140)  thing (-6.140)  #photo (-6.394)  big (-6.394)  get (-6.394)  going (-6.394)  made (-6.394)  may (-6.394)  new (-6.394)  one (-6.394)  really (-6.394)  thanks (-6.394)  time (-6.394)  awesome (-6.737)
#
# Country = de
# posted (-5.974)  enough (-6.228)  love (-6.228)  photo (-6.228)  #rosegold (-6.571)  almost (-6.571)  come (-6.571)  could (-6.571)  germany (-6.571)  im (-6.571)  kernen (-6.571)  miss (-6.571)  mkmedi (-6.571)  night (-6.571)  photodesign (-6.571)  please (-6.571)  remstal (-6.571)  week (-6.571)  year (-6.571)  #1yearofalmostisneverenough (-7.095)
#
# Country = gb
# got (-5.910)  beat (-6.113)  hope (-6.113)  x (-6.113)  always (-6.367)  day (-6.367)  fear (-6.367)  love (-6.367)  new (-6.367)  one (-6.367)  plz (-6.367)  sure (-6.367)  time (-6.367)  well (-6.367)  yeah (-6.367)  <3 (-6.710)  @skyhelpteam (-6.710)  babe (-6.710)  beautiful (-6.710)  come (-6.710)
#
# Country = id
# pic (-5.442)  others (-5.881)  coffee (-6.338)  donuts (-6.338)  photo (-6.338)  posted (-6.338)  rt (-6.338)  wkwk (-6.338)  @jcoindonesia (-6.680)  @justinbieber (-6.680)  banget (-6.680)  cafe (-6.680)  direction (-6.680)  ga (-6.680)  gulung (-6.680)  haha (-6.680)  happy (-6.680)  hari (-6.680)  ini (-6.680)  j.co (-6.680)
#
# Country = my
# selangor (-5.577)  jaya (-5.890)  petaling (-6.093)  thank (-6.093)  w (-6.093)  aku (-6.347)  haha (-6.347)  johor (-6.347)  nk (-6.347)  one (-6.347)  others (-6.347)  take (-6.347)  tu (-6.347)  @poemporns (-6.690)  abg (-6.690)  ak (-6.690)  ary (-6.690)  back (-6.690)  beb (-6.690)  can't (-6.690)
#
# Country = ph
# follow (-5.448)  please (-5.574)  :d (-6.089)  im (-6.089)  make (-6.089)  #hometomama (-6.344)  @iam3l (-6.344)  @justinbieber (-6.344)  back (-6.344)  city (-6.344)  come (-6.344)  dreams (-6.344)  ka (-6.344)  ko (-6.344)  lol (-6.344)  manila (-6.344)  may (-6.344)  mo (-6.344)  na (-6.344)  ng (-6.344)
#
# Country = sg
# singapore (-5.543)  park (-6.058)  w (-6.058)  work (-6.058)  batam (-6.313)  hotel (-6.313)  others (-6.313)  say (-6.313)  thanks (-6.313)  use (-6.313)  @tutiandonlyher (-6.655)  air (-6.655)  another (-6.655)  beach (-6.655)  east (-6.655)  fitness (-6.655)  food (-6.655)  keri (-6.655)  love (-6.655)  make (-6.655)
#
# Country = us
# get (-5.882)  go (-5.882)  u (-5.882)  going (-6.085)  like (-6.085)  love (-6.085)  boy (-6.339)  can't (-6.339)  feel (-6.339)  happy (-6.339)  home (-6.339)  hope (-6.339)  make (-6.339)  much (-6.339)  really (-6.339)  time (-6.339)  #allcity (-6.681)  already (-6.681)  beginning (-6.681)  better (-6.681)
#
# Country = za
# love (-5.479)  day (-5.749)  god (-5.917)  good (-5.917)  like (-5.917)  got (-6.120)  way (-6.120)  everything (-6.374)  guys (-6.374)  made (-6.374)  man (-6.374)  one (-6.374)  something (-6.374)  u (-6.374)  ur (-6.374)  weekend (-6.374)  @reflexwbc (-6.717)  award (-6.717)  back (-6.717)  best (-6.717)
#
# Classifier = Logistic Regression
#
#
# Country = au
# australia (1.947)  literally (1.635)  @micksunnyg (1.570)  instagrams (1.375)  spammed (1.375)  melbourne (1.370)  https://t.co/7rcjjptvl7 (1.323)  summerpoyi's (1.323)  @jackgilinsky (1.273)  @whennboys (1.273)  australian (1.222)  #melbourne (1.193)  @thomjrob (1.193)  great (1.184)  @christorrano (1.122)  http://t.co/blhj9cmxit (1.122)  @dasheryoung (1.115)  lachie (1.115)  @shell_07 (1.112)  freo (1.112)
#
# Country = ca
# thing (1.987)  @aliclarke (1.616)  works (1.470)  happen (1.431)  kids (1.332)  right (1.319)  really (1.318)  let's (1.306)  bed (1.270)  @lola9793 (1.257)  @cheetahbiatch (1.229)  xoxo (1.229)  joking (1.220)  beautiful (1.203)  first (1.122)  #nochillzone (1.115)  healthy (1.115)  fun (1.084)  carlyle (1.072)  manor (1.072)
#
# Country = de
# @fabiomarabini (1.835)  happened (1.738)  posted (1.331)  germany (1.320)  enough (1.317)  #truegrip (1.310)  gauting (1.310)  https://t.co/brkwmsvzrb (1.310)  https://t.co/i7j5pmd3mx (1.210)  workout (1.210)  bradford (1.189)  come (1.166)  #asksteven (1.108)  @stevenfhoney (1.108)  facetime (1.108)  @kelsxmclaughlin (1.105)  cannot (1.105)  bloody (1.070)  yay (1.052)  anne (1.044)
#
# Country = gb
# stressed (1.577)  x (1.539)  well (1.539)  http://t.co/w0tjrah9y7 (1.520)  interesting (1.520)  prom (1.520)  this'll (1.520)  always (1.451)  many (1.398)  plz (1.301)  yeah (1.277)  favouriteeee (1.255)  http://t.co/wbale6zrsq (1.255)  http://t.co/giq4dl9jcq (1.249)  modelling (1.249)  xx (1.222)  http://t.co/4yniyezb0n (1.198)  holly (1.168)  seeing (1.146)  @skyhelpteam (1.121)
#
# Country = id
# pic (2.040)  http://t.co/0uccot9gdn (1.920)  https://t.co/exshmyqmsl (1.651)  http://t.co/jjcyszki2y (1.608)  @farid_nugrahaa (1.411)  followback (1.411)  http://t.co/wyldhnlap4 (1.411)  pranciska (1.411)  change (1.408)  selamat (1.333)  wkwk (1.315)  @justinbieber (1.187)  world (1.148)  karaoke (1.143)  overboard (1.142)  sore (1.104)  @viccent22 (1.082)  strong (1.082)  made (1.067)  @brunomars (1.059)
#
# Country = my
# @poemporns (2.177)  thank (2.009)  selangor (1.882)  @juztakumi (1.808)  @siti_nurbalqish (1.796)  @12_maiii (1.465)  johor (1.462)  @aqmarnaimi_ (1.298)  hunny (1.298)  @markthewise (1.282)  depressing (1.282)  back (1.279)  news (1.217)  @_amewwa_ (1.174)  hekhek (1.174)  cave (1.157)  http://t.co/6qowzr40be (1.157)  #gunner (1.131)  http://t.co/utnamcqqx5 (1.131)  https://t.co/gqajzmp88o (1.122)
#
# Country = ph
# @home (1.761)  :d (1.564)  lol (1.507)  #sorrynotsorry (1.484)  @veronicavispo (1.484)  space (1.388)  http://t.co/fznyhrrj (1.351)  ko (1.330)  ng (1.292)  dye (1.242)  http://t.co/h0dlmhdtbf (1.160)  reco (1.160)  follow (1.155)  manila (1.147)  @relatlonshlp (1.131)  worry (1.131)  pastries (1.118)  perfection (1.118)  @jamalwade_ (1.095)  fairlane (1.095)
#
# Country = sg
# singapore (2.484)  @tutiandonlyher (1.885)  https://t.co/potgoiy5rv (1.861)  @ricadetiquez (1.744)  @dolly07397340 (1.488)  yepz (1.488)  caterpillar (1.332)  https://t.co/fcnojxrgld (1.332)  use (1.331)  @megaekaputri_ (1.298)  thanks (1.282)  perfect (1.257)  heart (1.185)  work (1.158)  hotel (1.156)  @thebeatles (1.156)  https://t.co/rwqvgoxm26 (1.156)  park (1.149)  capitol (1.135)  https://t.co/rm89lyui2a (1.135)
#
# Country = us
# http://t.co/ykkwnmzsir (1.730)  freakin (1.642)  @ansleytolbert (1.479)  @savannerdd (1.479)  can't (1.392)  heaven (1.390)  sheets (1.390)  u (1.389)  much (1.288)  weekend (1.261)  @b_diddddy (1.257)  ahhahaha (1.257)  clue (1.256)  beginning (1.213)  where's (1.146)  home (1.143)  happy (1.128)  boy (1.127)  go (1.116)  #5sosacousticatlanta (1.092)
#
# Country = za
# https://t.co/igzld1xpw2 (2.497)  man (2.000)  https://t.co/2fsyuigben (1.812)  good (1.522)  love (1.421)  god (1.342)  @spha_blose (1.324)  @ferlo_mabkay (1.317)  https://t.co/upndf1513q (1.317)  @fbotha1 (1.288)  kosciiiiiiielny (1.280)  homesweethomes (1.233)  https://t.co/wwshen9ovq (1.233)  makes (1.232)  journalist (1.227)  drawing (1.207)  goodnight (1.146)  weekend (1.131)  difficult (1.124)  blood (1.116)
